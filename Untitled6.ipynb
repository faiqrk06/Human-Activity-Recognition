# %% [markdown]
# #Active Learning approach on Heterogeneity Activity Recognition using Wearable sensors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install pydub

# %%
from warnings import filterwarnings
filterwarnings("ignore",category=DeprecationWarning)
filterwarnings("ignore", category=FutureWarning)
filterwarnings("ignore", category=UserWarning)
#GENERAL
import pandas as pd
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from keras import models
from keras import layers
import tensorflow as tf
from tensorflow.keras.applications import VGG16,VGG19,inception_v3
from keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.datasets import mnist
import keras
#SKLEARN CLASSIFIER
# from xgboost import XGBClassifier, XGBRegressor
# from lightgbm import LGBMClassifier, LGBMRegressor
# from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
#from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import regularizers
from sklearn.preprocessing import LabelEncoder
#ACCURACY CONTROL
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from warnings import filterwarnings
filterwarnings("ignore",category=DeprecationWarning)
filterwarnings("ignore", category=FutureWarning)
filterwarnings("ignore", category=UserWarning)
#GENERAL
import pandas as pd
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from keras import models
from keras import layers
import tensorflow as tf
from tensorflow.keras.applications import VGG16,VGG19,inception_v3
from keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.datasets import mnist
import keras
#SKLEARN CLASSIFIER
# from xgboost import XGBClassifier, XGBRegressor
# from lightgbm import LGBMClassifier, LGBMRegressor
# from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
#from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import regularizers
from sklearn.preprocessing import LabelEncoder
#ACCURACY CONTROL
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
#OPTIMIZER
# from keras.optimizers import Adam,Optimizer,Optimizer, SGD
from tensorflow.keras.optimizers import Adam,Optimizer,Optimizer, SGD
#MODEL LAYERS
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization,MaxPooling2D,BatchNormalization,\
                        Permute, TimeDistributed, Bidirectional,GRU, SimpleRNN,\
LSTM, GlobalAveragePooling2D, SeparableConv2D, ZeroPadding2D, Convolution2D, ZeroPadding2D,Reshape,\
Conv2DTranspose, LeakyReLU, Conv1D, AveragePooling1D, MaxPooling1D
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
#PATH PROCESS
import os
import os.path
from pathlib import Path
import glob
#IMAGE PROCESS
from PIL import Image
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from keras.applications.vgg16 import preprocess_input, decode_predictions
import imageio
from IPython.display import Image
import matplotlib.image as mpimg
#MUSIC PROCESS
import pydub
from scipy.io.wavfile import read, write
import librosa
import librosa.display
import IPython
from IPython.display import Audio
import scipy

# %%
#dataset1=r"/content/drive/MyDrive/Activity recognition exp/Copy of Watch_accelerometer.csv"
dataset2=r"/content/drive/MyDrive/Activity recognition exp/Copy of Watch_gyroscope.csv"

# %%
#dataframe1=pd.read_csv(dataset1)
dataframe2=pd.read_csv(dataset2)

# %%
dataframe1
# Out:
#          Index   Arrival_Time    Creation_Time         x          y         z  \
# 0            0  1424696638740   27920678471000 -0.565032  -9.572019 -0.614113
# 1            1  1424696638740   27920681910000 -0.832584  -9.713276 -0.606930
# 2            2  1424696638740   27920692014000 -1.018134  -9.935339 -0.544082
# 3            3  1424696638741   27920701983000 -1.222838 -10.142437 -0.566229
# 4            4  1424696638741   27920711906000 -1.577180 -10.480618 -0.402824
# ...        ...            ...              ...       ...        ...       ...
# 3540957  55520  1424778496409  205449746189955  4.416595  -8.708023 -1.715271
# 3540958  55521  1424778496409  205449751164320  5.337799  -9.526871 -1.222534
# 3540959  55522  1424778496409  205449756138686  6.580353  -9.748245 -1.291565
# 3540960  55523  1424778496409  205449761143569  7.932404  -9.514969 -1.608154
# 3540961  55525  1424778496409  205449771092299  9.981903  -9.026993 -0.558411
#
# ...

# %%
dataframe2
# Out:
#          Index   Arrival_Time    Creation_Time         x         y         z  \
# 0            0  1424696638743   27920678496000 -0.162187 -0.022104  0.059655
# 1            1  1424696638743   27920681926000 -0.183225 -0.061785  0.012517
# 2            2  1424696638743   27920692031000 -0.180829 -0.108657 -0.036485
# 3            3  1424696638743   27920701997000 -0.147805 -0.157925 -0.098537
# 4            7  1424696638744   27920743068000  0.182160 -0.323574 -0.277235
# ...        ...            ...              ...       ...       ...       ...
# 3205426  27417  1424778496411  205519488602851  0.062805  0.171570  0.093369
# 3205427  27418  1424778496411  205519493577216  0.093781  0.133118  0.083755
# 3205428  27419  1424778496411  205519498551581  0.105530  0.097870  0.058121
# 3205429  27420  1424778496411  205519503556464  0.122620  0.083984  0.038895
# 3205430  27421  1424778496411  205519508530829  0.150391  0.098938  0.050644
#
#         User    Model     Device     gt
# ...

# %%
string = ['User', 'Model','Device','gt']
for col in string:
    le = LabelEncoder()
    le.fit(dataframe1[col].astype(str))
    dataframe1[col] = le.transform(dataframe1[col].astype(str))

# %%
dataframe1
# Out:
#          Index   Arrival_Time    Creation_Time         x          y         z  \
# 0            0  1424696638740   27920678471000 -0.565032  -9.572019 -0.614113
# 1            1  1424696638740   27920681910000 -0.832584  -9.713276 -0.606930
# 2            2  1424696638740   27920692014000 -1.018134  -9.935339 -0.544082
# 3            3  1424696638741   27920701983000 -1.222838 -10.142437 -0.566229
# 4            4  1424696638741   27920711906000 -1.577180 -10.480618 -0.402824
# ...        ...            ...              ...       ...        ...       ...
# 3540957  55520  1424778496409  205449746189955  4.416595  -8.708023 -1.715271
# 3540958  55521  1424778496409  205449751164320  5.337799  -9.526871 -1.222534
# 3540959  55522  1424778496409  205449756138686  6.580353  -9.748245 -1.291565
# 3540960  55523  1424778496409  205449761143569  7.932404  -9.514969 -1.608154
# 3540961  55525  1424778496409  205449771092299  9.981903  -9.026993 -0.558411
#
#          User  Model  Device  gt
# ...

# %%
string = ['User', 'Model','Device','gt']
for col in string:
    le = LabelEncoder()
    le.fit(dataframe2[col].astype(str))
    dataframe2[col] = le.transform(dataframe2[col].astype(str))

# %%
dataframe2
# Out:
#          Index   Arrival_Time    Creation_Time         x         y         z  \
# 0            0  1424696638743   27920678496000 -0.162187 -0.022104  0.059655
# 1            1  1424696638743   27920681926000 -0.183225 -0.061785  0.012517
# 2            2  1424696638743   27920692031000 -0.180829 -0.108657 -0.036485
# 3            3  1424696638743   27920701997000 -0.147805 -0.157925 -0.098537
# 4            7  1424696638744   27920743068000  0.182160 -0.323574 -0.277235
# ...        ...            ...              ...       ...       ...       ...
# 3205426  27417  1424778496411  205519488602851  0.062805  0.171570  0.093369
# 3205427  27418  1424778496411  205519493577216  0.093781  0.133118  0.083755
# 3205428  27419  1424778496411  205519498551581  0.105530  0.097870  0.058121
# 3205429  27420  1424778496411  205519503556464  0.122620  0.083984  0.038895
# 3205430  27421  1424778496411  205519508530829  0.150391  0.098938  0.050644
#
#          User  Model  Device  gt
# ...

# %%
unique_labels = dataframe1['gt'].unique()
print("Unique Labels:", unique_labels)
# Out:
# Unique Labels: [5 1 2 6 4 3 0]

# %%
label_counts = dataframe1['gt'].value_counts()
print("Label Counts:")
print(label_counts)
# Out:
# Label Counts:
# 0    635530
# 6    549761
# 1    520357
# 3    486376
# 4    473754
# 5    451189
# 2    423995
# Name: gt, dtype: int64

# %%
label_counts = dataframe2['gt'].value_counts()
print("Label Counts:")
print(label_counts)
# Out:
# Label Counts:
# 0    522672
# 6    488309
# 1    470429
# 4    446023
# 5    430223
# 3    428241
# 2    419534
# Name: gt, dtype: int64

# %%
features = dataframe2.columns ## Fetching all Features Column names
## Applying Pearson Correaltion
mask = np.zeros_like(dataframe2[features].corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = True
## Creating a Plot Diagram
f, ax = plt.subplots(figsize=(16, 12))
## Title of Plot
# plt.title('Pearson Correlation Matrix',fontsize=27)
sns.heatmap(dataframe2[features].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="OrRd",
linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9});

# %%
## Dimensionlaity of the Model
print("Number of Rows:", dataframe2.shape[0])
print("Number of Columns:", dataframe2.shape[1])
# Out:
# Number of Rows: 3205431
# Number of Columns: 10

# %%
relevant_features = mask[mask>0.9] ## selecting features with 80% correlation
corr_matrix = dataframe2.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# %%
to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]
data = dataframe2.drop(dataframe2[to_drop], axis=1)
to_drop
# Out:
# ['Device']

# %%
corr_matrix = dataframe1.corr()

# generate a heatmap from the correlation matrix
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
X1 = dataframe1.drop(['gt'], axis=1).reset_index(drop=True)
Y1 = dataframe1['gt'].reset_index(drop=True)

# %%
X2 = dataframe2.drop(['gt'], axis=1).reset_index(drop=True)
Y2 = dataframe2['gt'].reset_index(drop=True)

# %% [markdown]
# Code to see if it gives less accuracy

# %% [markdown]
# Random forest gyroscope

# %%
#code 1
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample
    uncertain_sample = uncertainty.argmin()

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 2: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 3: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9999

# %%
#code 2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3
randomness_factor = 0.01  # Adjust this value to control randomness

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample with some randomness
    uncertain_sample = np.random.choice(np.where(uncertainty == uncertainty.min())[0])

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 2: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 3: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9999

# %% [markdown]
# XGBoost Gyroscope

# %%
#code 1
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = XGBClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample
    uncertain_sample = uncertainty.argmin()

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Iteration 2: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Iteration 3: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Best Accuracy: 0.9814

# %%
#code 2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3
randomness_factor = 0.01  # Adjust this value to control randomness

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = XGBClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample with some randomness
    uncertain_sample = np.random.choice(np.where(uncertainty == uncertainty.min())[0])

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Iteration 2: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Iteration 3: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Best Accuracy: 0.9814

# %%
#code 1
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = KNeighborsClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample
    uncertain_sample = uncertainty.argmin()

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Iteration 2: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Iteration 3: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Best Accuracy: 0.9926

# %%
#code 1
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample
    uncertain_sample = uncertainty.argmin()

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Iteration 2: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Iteration 3: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Best Accuracy: 0.9926

# %% [markdown]
# Decision Tree

# %%
#code 2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3
randomness_factor = 0.01  # Adjust this value to control randomness

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample with some randomness
    uncertain_sample = np.random.choice(np.where(uncertainty == uncertainty.min())[0])

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 2: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 3: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9999

# %%
#code 2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3
randomness_factor = 0.01  # Adjust this value to control randomness

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample with some randomness
    uncertain_sample = np.random.choice(np.where(uncertainty == uncertainty.min())[0])

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 2: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 3: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Best Accuracy: 0.9999

# %% [markdown]
# Gradient boosting

# %%
#code 1
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample
    uncertain_sample = uncertainty.argmin()

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")

# %%
#code 2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3
randomness_factor = 0.01  # Adjust this value to control randomness

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = GradientBoostingClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample with some randomness
    uncertain_sample = np.random.choice(np.where(uncertainty == uncertainty.min())[0])

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9479, F1 Score = 0.9476, Precision = 0.9480, Recall = 0.9479

# %%
from lightgbm import LGBMClassifier

# %%
#code 2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3
randomness_factor = 0.01  # Adjust this value to control randomness

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = LGBMClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)

    # Get the index of the least uncertain sample with some randomness
    uncertain_sample = np.random.choice(np.where(uncertainty == uncertainty.min())[0])

    # Add the least uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_train, [y_test.iloc[uncertain_sample]]))

    # Remove the least uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.425555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1545
# [LightGBM] [Info] Number of data points in the train set: 2404073, number of used features: 9
# [LightGBM] [Info] Start training from score -1.812944
# [LightGBM] [Info] Start training from score -1.920564
# [LightGBM] [Info] Start training from score -2.032106
# [LightGBM] [Info] Start training from score -2.012787
# [LightGBM] [Info] Start training from score -1.972085
# [LightGBM] [Info] Start training from score -2.008070
# [LightGBM] [Info] Start training from score -1.882469
# Iteration 1: Accuracy = 0.9818, F1 Score = 0.9818, Precision = 0.9818, Recall = 0.9818
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.221369 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %% [markdown]
# # ***Random*** ***Forest***

# %% [markdown]
# # Watch's Accelometer

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 2: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 3: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9998

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    158522
#            1       1.00      1.00      1.00    130706
#            2       1.00      1.00      1.00    105889
#            3       1.00      1.00      1.00    121424
#            4       1.00      1.00      1.00    118673
#            5       1.00      1.00      1.00    112415
#            6       1.00      1.00      1.00    137611
#
#     accuracy                           1.00    885240
#    macro avg       1.00      1.00      1.00    885240
# weighted avg       1.00      1.00      1.00    885240

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #Watch Gyroscope

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 2: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 3: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9998

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    130392
#            1       1.00      1.00      1.00    118174
#            2       1.00      1.00      1.00    104457
#            3       1.00      1.00      1.00    107019
#            4       1.00      1.00      1.00    111457
#            5       1.00      1.00      1.00    107482
#            6       1.00      1.00      1.00    122376
#
#     accuracy                           1.00    801357
#    macro avg       1.00      1.00      1.00    801357
# weighted avg       1.00      1.00      1.00    801357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Watch Accelometer

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, f1_score
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# accuracies = []
# f1_measure_list = []
# precision_list = []  # List to store precision values
# recall_list = []     # List to store recall values
# num_iterations = 1

# # Start the loop for a certain number of iterations
# for i in range(num_iterations):
#     # Split the data into train and test sets
#     X_train, X_test, y_train, y_test = train_test_split(X3, Y3, test_size=0.25, random_state=0)
#     X_train = X_train.reset_index(drop=True)
#     X_test = X_test.reset_index(drop=True)
#     y_train = y_train.reset_index(drop=True)
#     y_test = y_test.reset_index(drop=True)

#     # Train the model using the current labeled data
#     model = RandomForestClassifier()
#     model.fit(X_train, y_train)
#     uncertainty = model.predict_proba(X_test).max(axis=1)
#         # Get the index of the most uncertain sample
#     uncertain_sample = uncertainty.argmax()

#     # Add the uncertain sample to the labeled data
#     X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
#     y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

#     # Remove the uncertain sample from the test set
#     X_test = X_test.drop(index=uncertain_sample)
#     y_test.pop(uncertain_sample)

#     # Make predictions on the test set
#     y_pred = model.predict(X_test)

#     # Calculate the accuracy of the model
#     accuracy = accuracy_score(y_test, y_pred)
#     f1_measure = f1_score(y_test, y_pred, average='weighted')
#     precision = precision_score(y_test, y_pred, average='weighted')
#     recall = recall_score(y_test, y_pred, average='weighted')

#     accuracies.append(accuracy)
#     f1_measure_list.append(f1_measure)
#     precision_list.append(precision)
#     recall_list.append(recall)

#     print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

# best_iteration = np.argmax(accuracies)
# best_accuracy = accuracies[best_iteration]
# print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9998

# %% [markdown]
# Watch Gyroscoope

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, f1_score
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
# accuracies = []
# f1_measure_list = []
# precision_list = []  # List to store precision values
# recall_list = []     # List to store recall values
# num_iterations = 1

# # Start the loop for a certain number of iterations
# for i in range(num_iterations):
#     # Split the data into train and test sets
#     X_train, X_test, y_train, y_test = train_test_split(X4, Y4, test_size=0.25, random_state=0)
#     X_train = X_train.reset_index(drop=True)
#     X_test = X_test.reset_index(drop=True)
#     y_train = y_train.reset_index(drop=True)
#     y_test = y_test.reset_index(drop=True)

#     # Train the model using the current labeled data
#     model = RandomForestClassifier()
#     model.fit(X_train, y_train)
#     uncertainty = model.predict_proba(X_test).max(axis=1)
#         # Get the index of the most uncertain sample
#     uncertain_sample = uncertainty.argmax()

#     # Add the uncertain sample to the labeled data
#     X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
#     y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

#     # Remove the uncertain sample from the test set
#     X_test = X_test.drop(index=uncertain_sample)
#     y_test.pop(uncertain_sample)

#     # Make predictions on the test set
#     y_pred = model.predict(X_test)

#     # Calculate the accuracy of the model
#     accuracy = accuracy_score(y_test, y_pred)
#     f1_measure = f1_score(y_test, y_pred, average='weighted')
#     precision = precision_score(y_test, y_pred, average='weighted')
#     recall = recall_score(y_test, y_pred, average='weighted')

#     accuracies.append(accuracy)
#     f1_measure_list.append(f1_measure)
#     precision_list.append(precision)
#     recall_list.append(recall)

#     print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

# best_iteration = np.argmax(accuracies)
# best_accuracy = accuracies[best_iteration]
# print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9998

# %% [markdown]
# XGBOOST

# %% [markdown]
# #Accelerometer

# %%
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = XGBClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9826, F1 Score = 0.9826, Precision = 0.9826, Recall = 0.9826
# Iteration 2: Accuracy = 0.9826, F1 Score = 0.9826, Precision = 0.9826, Recall = 0.9826
# Iteration 3: Accuracy = 0.9826, F1 Score = 0.9826, Precision = 0.9826, Recall = 0.9826
# Best Accuracy: 0.9826

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    158522
#            1       0.98      0.98      0.98    130706
#            2       1.00      1.00      1.00    105890
#            3       0.96      0.95      0.95    121424
#            4       0.95      0.96      0.95    118673
#            5       1.00      1.00      1.00    112414
#            6       0.99      1.00      0.99    137611
#
#     accuracy                           0.98    885240
#    macro avg       0.98      0.98      0.98    885240
# weighted avg       0.98      0.98      0.98    885240

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #Xgboost Gyroscope

# %%
from xgboost import XGBClassifier

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = XGBClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled datal
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Iteration 2: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Iteration 3: Accuracy = 0.9814, F1 Score = 0.9814, Precision = 0.9814, Recall = 0.9814
# Best Accuracy: 0.9814

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    130392
#            1       0.98      0.97      0.98    118174
#            2       0.99      1.00      1.00    104458
#            3       0.96      0.94      0.95    107019
#            4       0.95      0.96      0.95    111457
#            5       1.00      1.00      1.00    107481
#            6       0.99      1.00      0.99    122376
#
#     accuracy                           0.98    801357
#    macro avg       0.98      0.98      0.98    801357
# weighted avg       0.98      0.98      0.98    801357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #KNN Accelerometer

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = KNeighborsClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9935, F1 Score = 0.9935, Precision = 0.9935, Recall = 0.9935
# Iteration 2: Accuracy = 0.9935, F1 Score = 0.9935, Precision = 0.9935, Recall = 0.9935
# Iteration 3: Accuracy = 0.9935, F1 Score = 0.9935, Precision = 0.9935, Recall = 0.9935
# Best Accuracy: 0.9935

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    158522
#            1       0.99      0.99      0.99    130706
#            2       1.00      1.00      1.00    105889
#            3       0.98      0.98      0.98    121424
#            4       0.99      0.99      0.99    118673
#            5       1.00      1.00      1.00    112415
#            6       1.00      1.00      1.00    137611
#
#     accuracy                           0.99    885240
#    macro avg       0.99      0.99      0.99    885240
# weighted avg       0.99      0.99      0.99    885240

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #KNN Gyroscope

# %%
accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = KNeighborsClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Iteration 2: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Iteration 3: Accuracy = 0.9926, F1 Score = 0.9926, Precision = 0.9926, Recall = 0.9926
# Best Accuracy: 0.9926

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    130392
#            1       0.99      0.99      0.99    118174
#            2       1.00      1.00      1.00    104457
#            3       0.98      0.98      0.98    107019
#            4       0.99      0.99      0.99    111457
#            5       1.00      1.00      1.00    107482
#            6       1.00      1.00      1.00    122376
#
#     accuracy                           0.99    801357
#    macro avg       0.99      0.99      0.99    801357
# weighted avg       0.99      0.99      0.99    801357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #Decision Tree Accelerometer

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9997, F1 Score = 0.9997, Precision = 0.9997, Recall = 0.9997
# Iteration 2: Accuracy = 0.9997, F1 Score = 0.9997, Precision = 0.9997, Recall = 0.9997
# Iteration 3: Accuracy = 0.9997, F1 Score = 0.9997, Precision = 0.9997, Recall = 0.9997
# Best Accuracy: 0.9997

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    158522
#            1       1.00      1.00      1.00    130706
#            2       1.00      1.00      1.00    105889
#            3       1.00      1.00      1.00    121424
#            4       1.00      1.00      1.00    118673
#            5       1.00      1.00      1.00    112415
#            6       1.00      1.00      1.00    137611
#
#     accuracy                           1.00    885240
#    macro avg       1.00      1.00      1.00    885240
# weighted avg       1.00      1.00      1.00    885240

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #Decision Tree Gyroscope

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9999, F1 Score = 0.9999, Precision = 0.9999, Recall = 0.9999
# Iteration 2: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Iteration 3: Accuracy = 0.9998, F1 Score = 0.9998, Precision = 0.9998, Recall = 0.9998
# Best Accuracy: 0.9999

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    130392
#            1       1.00      1.00      1.00    118174
#            2       1.00      1.00      1.00    104457
#            3       1.00      1.00      1.00    107019
#            4       1.00      1.00      1.00    111457
#            5       1.00      1.00      1.00    107482
#            6       1.00      1.00      1.00    122376
#
#     accuracy                           1.00    801357
#    macro avg       1.00      1.00      1.00    801357
# weighted avg       1.00      1.00      1.00    801357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #Gradient Boosting Accelerometer

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = GradientBoostingClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9426, F1 Score = 0.9424, Precision = 0.9427, Recall = 0.9426
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-72feaca3a0ca> in <cell line: 11>()
#      19     # Train the model using the current labeled data
#      20     model = GradientBoostingClassifier()
# ---> 21     model.fit(X_train, y_train)
#      22     uncertainty = model.predict_proba(X_test).max(axis=1)
#      23         # Get the index of the most uncertain sample
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     536
#     537         # fit the boosting stages
# --> 538         n_stages = self._fit_stages(
#     539             X,
#     540             y,
#
# ...

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    158522
#            1       0.95      0.90      0.92    130706
#            2       0.98      0.99      0.99    105890
#            3       0.88      0.84      0.86    121424
#            4       0.84      0.88      0.86    118673
#            5       0.99      1.00      0.99    112414
#            6       0.97      0.99      0.98    137611
#
#     accuracy                           0.94    885240
#    macro avg       0.94      0.94      0.94    885240
# weighted avg       0.94      0.94      0.94    885240

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #Gradient Boosting Gyroscope

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = GradientBoostingClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Iteration 1: Accuracy = 0.9479, F1 Score = 0.9476, Precision = 0.9480, Recall = 0.9479
# Iteration 2: Accuracy = 0.9479, F1 Score = 0.9476, Precision = 0.9480, Recall = 0.9479
# Iteration 3: Accuracy = 0.9479, F1 Score = 0.9476, Precision = 0.9480, Recall = 0.9479
# Best Accuracy: 0.9479

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    130392
#            1       0.96      0.88      0.92    118174
#            2       0.98      0.98      0.98    104458
#            3       0.87      0.90      0.89    107019
#            4       0.90      0.88      0.89    111457
#            5       0.98      1.00      0.99    107481
#            6       0.95      0.99      0.97    122376
#
#     accuracy                           0.95    801357
#    macro avg       0.95      0.95      0.95    801357
# weighted avg       0.95      0.95      0.95    801357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %%
from lightgbm import LGBMClassifier

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = LGBMClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.470939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1545
# [LightGBM] [Info] Number of data points in the train set: 2655721, number of used features: 9
# [LightGBM] [Info] Start training from score -1.716938
# [LightGBM] [Info] Start training from score -1.919220
# [LightGBM] [Info] Start training from score -2.122090
# [LightGBM] [Info] Start training from score -1.984706
# [LightGBM] [Info] Start training from score -2.012126
# [LightGBM] [Info] Start training from score -2.059138
# [LightGBM] [Info] Start training from score -1.863084
# Iteration 1: Accuracy = 0.9830, F1 Score = 0.9830, Precision = 0.9830, Recall = 0.9830
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.156858 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    158521
#            1       0.98      0.98      0.98    130706
#            2       1.00      1.00      1.00    105890
#            3       0.95      0.96      0.96    121424
#            4       0.96      0.95      0.95    118673
#            5       1.00      1.00      1.00    112415
#            6       0.99      0.99      0.99    137611
#
#     accuracy                           0.98    885240
#    macro avg       0.98      0.98      0.98    885240
# weighted avg       0.98      0.98      0.98    885240

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()

# %%
 from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

accuracies = []
f1_measure_list = []
precision_list = []  # List to store precision values
recall_list = []     # List to store recall values
num_iterations = 3

# Start the loop for a certain number of iterations
for i in range(num_iterations):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X2, Y2, test_size=0.25, random_state=0)
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Train the model using the current labeled data
    model = LGBMClassifier()
    model.fit(X_train, y_train)
    uncertainty = model.predict_proba(X_test).max(axis=1)
        # Get the index of the most uncertain sample
    uncertain_sample = uncertainty.argmax()

    # Add the uncertain sample to the labeled data
    X_train = np.concatenate((X_train, [X_test.iloc[uncertain_sample]]))
    y_train = np.concatenate((y_test, [y_test.iloc[uncertain_sample]]))

    # Remove the uncertain sample from the test set
    X_test = X_test.drop(index=uncertain_sample)
    y_test.pop(uncertain_sample)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy of the model
    accuracy = accuracy_score(y_test, y_pred)
    f1_measure = f1_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')

    accuracies.append(accuracy)
    f1_measure_list.append(f1_measure)
    precision_list.append(precision)
    recall_list.append(recall)

    print(f"Iteration {i+1}: Accuracy = {accuracy:.4f}, F1 Score = {f1_measure:.4f}, Precision = {precision:.4f}, Recall = {recall:.4f}")

best_iteration = np.argmax(accuracies)
best_accuracy = accuracies[best_iteration]
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.090541 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1545
# [LightGBM] [Info] Number of data points in the train set: 2404073, number of used features: 9
# [LightGBM] [Info] Start training from score -1.812944
# [LightGBM] [Info] Start training from score -1.920564
# [LightGBM] [Info] Start training from score -2.032106
# [LightGBM] [Info] Start training from score -2.012787
# [LightGBM] [Info] Start training from score -1.972085
# [LightGBM] [Info] Start training from score -2.008070
# [LightGBM] [Info] Start training from score -1.882469
# Iteration 1: Accuracy = 0.9818, F1 Score = 0.9818, Precision = 0.9818, Recall = 0.9818
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.082897 seconds.
# ...

# %%
# make predictions on the test set
y_pred = model.predict(X_test)

# calculate the confusion matrixa
cm = confusion_matrix(y_test, y_pred)

# plot the confusion matrix using seaborn
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    130392
#            1       0.98      0.98      0.98    118173
#            2       1.00      1.00      1.00    104458
#            3       0.95      0.95      0.95    107019
#            4       0.95      0.96      0.95    111457
#            5       1.00      1.00      1.00    107482
#            6       0.99      0.99      0.99    122376
#
#     accuracy                           0.98    801357
#    macro avg       0.98      0.98      0.98    801357
# weighted avg       0.98      0.98      0.98    801357

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc


# Predict probabilities for each class
y_pred_prob = model.predict_proba(X_test)

# Compute ROC curve and ROC area for each class
plt.figure()
for i in range(7):
    fpr, tpr, _ = roc_curve(y_test == i, y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) for 7 Classes')
plt.legend(loc='lower right')
plt.show()
